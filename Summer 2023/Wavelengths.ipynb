# %%
import sys
import os, os.path
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import csv
from scipy.stats import kde
import pandas as pd
from matplotlib import gridspec


myfile = pd.read_csv('/home/smu/Carlos/APOGEE_STDS/Nazgul/bh261_1_236.fitscorrected.out', delimiter = ' ')
myfile.columns = ["S", "lambda", "flux"] # , "yr"

x = myfile['lambda']
y = myfile['flux']

yourfile = pd.read_csv('/home/smu/Carlos/SPACE/p_files/bh261_1_236.fitsC_model.dat', delimiter = '\s+')
yourfile.columns = ["one", "two", "three", "four", "five", "six", "seven"]

x1 = yourfile['one']
y1 = yourfile['two']

fig = plt.figure(figsize = (8,6))

plt.plot(x,y, color = 'grey', linewidth = 1.75, label = 'AAT Spectra')
plt.plot(x1,y1, linestyle = '--', linewidth = .5, color = 'red', label = 'SP_Ace Fitting')
plt.axvline(x = (8450), color = 'red', linestyle = '-.', label = 'limits')
plt.title('Campos')
plt.xlabel('Wavelength [A]', fontsize = 14, fontweight = "bold")
plt.ylabel('Normalized Flux', fontsize = 14, fontweight = "bold")

plt.axvline(x = (8450), color = 'red', linestyle = '-.')
    
plt.axvline(x = (8493), color = 'red', linestyle = '-.')
plt.axvline(x = (8503), color = 'red', linestyle = '-.')
plt.axvline(x = (8535), color = 'red', linestyle = '-.')
plt.axvline(x = (8550), color = 'red', linestyle = '-.')
plt.axvline(x = (8660), color = 'red', linestyle = '-.')
plt.axvline(x = (8670), color='red', linestyle = '-.')
    
plt.axvline(x = (8800), color = 'red', linestyle = '-.')
plt.ylim([0.3,1.2])
plt.xlim([8420,8870])
plt.legend(loc = 'lower right')
plt.savefig('campos.jpg')

# %%
myfile = pd.read_csv('/home/smu/Carlos/APOGEE_STDS/Nazgul/bh261_1_236.fitscorrected.out', delimiter = ' ')
myfile.columns = ["S", "lambda", "flux"] # , "yr"

x = myfile['lambda']
y = myfile['flux']


theirfile = pd.read_csv('/home/smu/Carlos/SPACE/p_files/bh261_1_236.fitsK_model.dat', delimiter = '\s+')
theirfile.columns = ["one", "two", "three", "four", "five", "six", "seven"]

x4 = theirfile['one']
y4 = theirfile['two']


fig = plt.figure(figsize = (8,6))

plt.plot(x,y, color = 'grey', linewidth = 1.75, label = 'AAT Spectra')
plt.plot(x4,y4, linestyle = '--', linewidth = .5, color = 'blue', label = 'SP_Ace Fitting')
plt.axvline(x = (8505), color = 'blue', linestyle = '-.', label = 'limits')
plt.title('Koch')
plt.xlabel('Wavelength [A]', fontsize = 14, fontweight = "bold")
plt.ylabel('Normalized Flux', fontsize = 14, fontweight = "bold")

plt.axvline(x = (8505), color = 'blue', linestyle = '-.')

plt.axvline(x = (8535), color = 'blue', linestyle = '-.')
plt.axvline(x = (8547), color = 'blue', linestyle = '-.')
plt.axvline(x = (8660), color = 'blue', linestyle = '-.')
plt.axvline(x = (8670), color = 'blue', linestyle = '-.')
plt.axvline(x = (8535), color = 'blue', linestyle = '-.')
plt.axvline(x = (8660), color = 'blue', linestyle = '-.')
plt.axvline(x = (8670), color = 'blue', linestyle = '-.')

plt.axvline(x = (8702), color = 'blue', linestyle = '-.')

plt.ylim([0.3,1.2])
plt.xlim([8420,8870])
plt.legend(loc = 'lower right')
plt.savefig('koch.jpg')

# %%
myfile = pd.read_csv('/home/smu/Carlos/APOGEE_STDS/Nazgul/bh261_1_236.fitscorrected.out', delimiter = ' ')
myfile.columns = ["S", "lambda", "flux"] #, "yr"

x = myfile['lambda']
y = myfile['flux']


theirfile = pd.read_csv('/home/smu/Carlos/SPACE/p_files/bh261_1_236.fitsF_model.dat', delimiter = '\s+')
theirfile.columns = ["one", "two", "three", "four", "five", "six", "seven"]

x3 = theirfile['one']
y3 = theirfile['two']


fig = plt.figure(figsize = (8,6))

plt.plot(x,y, color = 'grey', linewidth = 1.75, label = 'AAT Spectra')
plt.plot(x3,y3, linestyle = '--', linewidth = .5, color = 'purple', label = 'SP_Ace Fitting')
plt.axvline(x = (8500), color = 'purple', linestyle = '-.', label = 'limits')
plt.title('Full')
plt.xlabel('Wavelength [A]', fontsize = 14, fontweight = "bold")
plt.ylabel('Normalized Flux', fontsize = 14, fontweight = "bold")

plt.axvline(x = (8500), color = 'purple', linestyle = '-.')
plt.axvline(x = (8855), color = 'purple', linestyle = '-.')

plt.ylim([0.3,1.2])
plt.xlim([8420,8870])
plt.legend(loc = 'lower right')
plt.savefig('full.jpg')

# %%
myfile = pd.read_csv('/home/smu/Carlos/APOGEE_STDS/Nazgul/bh261_1_236.fitscorrected.out', delimiter = ' ')
myfile.columns = ["S", "lambda", "flux"] #, "yr"

x = myfile['lambda']
y = myfile['flux']


theirfile = pd.read_csv('/home/smu/Carlos/SPACE/p_files/bh261_1_236.fitsD_model.dat', delimiter = '\s+')
theirfile.columns = ["one", "two", "three", "four", "five", "six", "seven"]

x2 = theirfile['one']
y2 = theirfile['two']


fig = plt.figure(figsize = (8,6))

plt.plot(x,y, color = 'grey', linewidth = 1.75, label = 'AAT Spectra')
plt.plot(x2,y2, linestyle = '--', linewidth = .5, color = 'orange', label = 'SP_Ace Fitting')
plt.axvline(x = (8450), color='orange', linestyle = '-.', label = 'limits')
plt.title('Delta')
plt.xlabel('Wavelength [A]', fontsize = 14, fontweight = "bold")
plt.ylabel('Normalized Flux', fontsize = 14, fontweight = "bold")

plt.axvline(x = (8450), color='orange', linestyle = '-.')

plt.axvline(x = (8490), color='orange', linestyle = '-.')
plt.axvline(x = (8505), color='orange', linestyle = '-.')
plt.axvline(x = (8535), color='orange', linestyle = '-.')
plt.axvline(x = (8550), color='orange', linestyle = '-.')
plt.axvline(x = (8655), color='orange', linestyle = '-.')
plt.axvline(x = (8670), color='orange', linestyle = '-.')
plt.axvline(x = (8750), color='orange', linestyle = '-.')
plt.axvline(x = (8798), color='orange', linestyle = '-.')

plt.axvline(x = (8813), color='orange', linestyle = '-.')

plt.ylim([0.3,1.2])
plt.xlim([8420,8870])
plt.legend(loc = 'lower right')
plt.savefig('delta.jpg')
